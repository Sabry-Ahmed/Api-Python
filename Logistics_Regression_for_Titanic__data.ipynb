# %% [markdown]
# <a href="https://colab.research.google.com/github/Sabry-Ahmed/Api-Python/blob/main/Logistics_Regression_for_Titanic__data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importer vos librairies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import linear_model #modèle linéaire
from sklearn.metrics import mean_squared_error, r2_score #métriques d'évaluation

# %%
df_gender_submission = pd.read_csv("/content/gender_submission.csv", sep=",")
df_test = pd.read_csv("/content/test.csv", sep=",")
df_train = pd.read_csv("/content/train.csv", sep=",")



print("Data loaded.")
# Out:
# Data loaded.

# %%
df_test["Cabin"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 413     NaN
# 414    C105
# 415     NaN
# 416     NaN
# 417     NaN
# Name: Cabin, Length: 418, dtype: object

# %%
print(len(df_train))
# Out:
# 891

# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt




plt.figure(figsize=(10, 6))
msno.matrix(df_train, figsize=(10,6), fontsize=8, labels=True, color=(0.25, 0.45, 0.6))
plt.show()

# %%
df_train["Age"].isnull().mean() * 100
# Out:
# 19.865319865319865

# %%
plt.figure(figsize=(8, 6))
plt.hist(df_test['Age'], bins=20, color='grey', edgecolor='black')
plt.xlabel("Age")
plt.ylabel("density")
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
moyenne = df_train["Age"].median()
medianne = df_train["Age"].mean()

# Print the results
print(f"moyenne: {moyenne:.2f}")
print(f"medianne: {medianne:.2f}")
# Out:
# moyenne: 28.00
# medianne: 29.70

# %%
df_train["Cabin"].isnull().mean() * 100
# Out:
# 77.10437710437711

# %%
df_train["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
embarked_distribution = df_train["Embarked"].value_counts()


plt.bar(embarked_distribution.index, embarked_distribution.values, color=['blue', 'green', 'orange'])
plt.title("Boarded Passengers Grouped by Port of Embarkation")
plt.xlabel("Port of Embarkation")
plt.ylabel("Number of Passengers")
plt.xticks(rotation=0)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))

ax.hist(df_train['Age'], bins=20, color='blue', alpha=0.7, label='Before Processing')

df_train["Age"].fillna(28, inplace=True)

ax.hist(df_train['Age'], bins=20, color='green', alpha=0.7, label='After Processing')

plt.title("Age Distribution Before and After Processing")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.grid(axis='y', alpha=0.75)
plt.legend()

plt.show()

# %%
df_train["Age"].fillna(28, inplace=True)

most_common_embarked = df_train["Embarked"].mode()[0]

df_train["Embarked"].fillna(most_common_embarked, inplace=True)

df_train.drop("Cabin", axis=1, inplace=True)

df_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-106d57488766> in <cell line: 1>()
# ----> 1 df_train["Age"].fillna(28, inplace=True)
#       2
#       3 most_common_embarked = df_train["Embarked"].mode()[0]
#       4
#       5 df_train["Embarked"].fillna(most_common_embarked, inplace=True)
#
# NameError: name 'df_train' is not defined
